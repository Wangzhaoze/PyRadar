# %%
import sys
import os
# setup work directory
current_dir = os.getcwd()
work_dir = os.path.abspath(os.path.join(current_dir, "../"))
os.chdir(work_dir)
sys.path.append(work_dir)
work_dir
# Out:
# 'c:\\Project_HOME\\pyradar'

# %%
from pyradar.base.radar import Radar
radar = Radar.load('examples/configs/TI-MMWCAS-RF-EVM.yaml')

radar.transceivers.show()
radar.waveform.show()
